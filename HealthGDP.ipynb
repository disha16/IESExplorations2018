# %%
import pandas as pd
import statsmodels.api as sm
import scipy
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import matplotlib.pylab as plt
import seaborn as sns
from statsmodels.graphics.tsaplots import plot_pacf
df2 = pd.read_csv("C:\Users\Rawal Rawal\Downloads\Tab98.csv",thousands=',')
df2.head()
# Out:
#                                           Indicators  Andhra Pradesh    Assam  \
# 0                         Population 2001 ( in ?000)         76210.0  26656.0
# 1                        Population 2011 ( in ?000)          84581.0  31206.0
# 2  Percentage decadal growth rate of population (...            14.6     18.9
# 3  Percentage decadal growth rate of population (...            11.0     17.1
# 4            Sex-ratio 2001 (Females per 1000 males)           978.0    935.0
#
#       Bihar  Chhattisgarh  Gujarat  Haryana  Himachal Pradesh  \
# 0   82999.0       20834.0  50671.0  21145.0            6078.0
# 1  104099.0       25545.0  60439.0  25351.0            6865.0
# 2      28.6          18.3     22.7     28.4              17.5
# 3      25.4          22.6     19.3     19.9              12.9
# 4     919.0         989.0    920.0    861.0             968.0
#
#    Jammu & Kashmir  Jharkhand     ...      Madhya Pradesh  Maharashtra  \
# ...

# %%
df3 = df2[df2['Indicators'].isin(["Per Capita","Health Index 2008"])]
# Create dataframe
df3.index = df3['Indicators']
del df3['Indicators']
df31 = df3.T

p1 = sns.regplot(data=df31, x="Health Index 2008", y="Per Capita", fit_reg=False, marker="+", color="skyblue")

# %%
# Out:
# Indicators       Health Index 2008 Per Capita
# Andhra Pradesh                0.58     142054
# Assam                        0.407      60952
# Bihar                        0.563      34168
# Chhattisgarh                 0.417      91772
# Gujarat                      0.633     156691
# Haryana                      0.627     196982
# Himachal Pradesh             0.717     158462
# Jammu & Kashmir               0.53      72958
# Jharkhand                      0.5      62816
# Karnataka                    0.627     157474
# Kerala                       0.817     162718
# Madhya Pradesh                0.43      72599
# Maharashtra                   0.65     180596
# Odisha                        0.45      75223
# Punjab                       0.667     142958
# Rajasthan                    0.587     100551
# Tamil Nadu                   0.637     157116
# Uttar Pradesh                0.473      48520
# Uttarakhand                   0.53     177356
# ...
