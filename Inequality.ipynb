# %%
import pandas as pd
import statsmodels.api as sm
import scipy
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import matplotlib.pylab as plt
import seaborn as sns
from statsmodels.graphics.tsaplots import plot_pacf
df2 = pd.read_csv("C:\Users\Rawal Rawal\Downloads\Tab98.csv",thousands=',')
df2.head()
# Out:
#                                           Indicators  Andhra Pradesh    Assam  \
# 0                         Population 2001 ( in ?000)         76210.0  26656.0
# 1                        Population 2011 ( in ?000)          84581.0  31206.0
# 2  Percentage decadal growth rate of population (...            14.6     18.9
# 3  Percentage decadal growth rate of population (...            11.0     17.1
# 4            Sex-ratio 2001 (Females per 1000 males)           978.0    935.0
#
#       Bihar  Chhattisgarh  Gujarat  Haryana  Himachal Pradesh  \
# 0   82999.0       20834.0  50671.0  21145.0            6078.0
# 1  104099.0       25545.0  60439.0  25351.0            6865.0
# 2      28.6          18.3     22.7     28.4              17.5
# 3      25.4          22.6     19.3     19.9              12.9
# 4     919.0         989.0    920.0    861.0             968.0
#
#    Jammu & Kashmir  Jharkhand     ...      Madhya Pradesh  Maharashtra  \
# ...

# %%
df3 = df2[df2['Indicators'].isin(["Urban Average MPCE 2009-10 (in `)","Rural Average MPCE 2009-10 (in `)","Education Index 2007-08"])]
df3.index = df3['Indicators']
del df3['Indicators']
df31 = df3.T
df31['Urban Average MPCE 2009-10 (in `)']= df31['Urban Average MPCE 2009-10 (in `)'].apply(float)
df31['Rural Average MPCE 2009-10 (in `)']= df31['Rural Average MPCE 2009-10 (in `)'].apply(float)
df31['Diff'] = ((df31['Urban Average MPCE 2009-10 (in `)']- df31['Rural Average MPCE 2009-10 (in `)'])/df31['Rural Average MPCE 2009-10 (in `)'])
df31['Diff']= df31['Diff']*100

del df31["Rural Average MPCE 2009-10 (in `)"]
del df31["Urban Average MPCE 2009-10 (in `)"]
p1 = sns.regplot(data=df31, x="Education Index 2007-08", y="Diff", fit_reg=False, marker="+", color="skyblue")

# %%
df4 = df2[df2['Indicators'].isin(["Urban Average MPCE 2009-10 (in `)","Rural Average MPCE 2009-10 (in `)","Health Index 2008"])]
df4.index = df4['Indicators']
del df4['Indicators']
df41 = df4.T
df41['Urban Average MPCE 2009-10 (in `)']= df41['Urban Average MPCE 2009-10 (in `)'].apply(float)
df41['Rural Average MPCE 2009-10 (in `)']= df41['Rural Average MPCE 2009-10 (in `)'].apply(float)
df41['Diff'] = ((df41['Urban Average MPCE 2009-10 (in `)']- df41['Rural Average MPCE 2009-10 (in `)'])/df41['Rural Average MPCE 2009-10 (in `)'])
df41['Diff']= df41['Diff']*100

del df41["Rural Average MPCE 2009-10 (in `)"]
del df41["Urban Average MPCE 2009-10 (in `)"]
p1 = sns.regplot(data=df41, x="Health Index 2008", y="Diff", fit_reg=False, marker="+", color="skyblue")
