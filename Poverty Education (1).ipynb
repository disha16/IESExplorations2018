# %%
import pandas as pd
import statsmodels.api as sm
import scipy
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import matplotlib.pylab as plt
import seaborn as sns
from statsmodels.graphics.tsaplots import plot_pacf
df2 = pd.read_csv("C:\Users\Rawal Rawal\Downloads\Tab98.csv",thousands=',')

# %%
df3 = df2[df2['Indicators'].isin(["2011-12 (Rural)","Education Index 2007-08"])]
# Create dataframe
df3.index = df3['Indicators']
del df3['Indicators']
df31 = df3.T

p1 = sns.regplot(data=df31, x="Education Index 2007-08", y="2011-12 (Rural)", fit_reg=False, marker="+", color="skyblue")
